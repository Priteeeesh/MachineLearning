# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
df=np.genfromtxt('DataSet.csv',delimiter=',',skip_header=1)
df=pd.DataFrame(df)
df.columns=['O','a','b','c','d','e','f','g','h','i','j']
df.drop(columns=['O'],inplace=True)
df
# Out:
#          a         b         c          d         e         f          g  \
# 0    3.201  5.774701  3.429272   0.108732 -0.146594 -2.140013   8.025347
# 1    1.066  0.519693  5.936320   0.194729 -1.031533  0.678119  12.408875
# 2    1.395  6.184605  4.393927   0.236128 -0.306630 -1.152583  12.271188
# 3    0.062  0.106774  0.227877   0.241525 -1.734883 -2.111483  12.531931
# 4    1.416  7.687776  3.696551   0.416807 -0.167303 -1.977925  12.915153
# ..     ...       ...       ...        ...       ...       ...        ...
# 994  1.866  2.950051  1.702322  11.655344 -1.059964 -0.484756  13.566640
# 995  0.966  2.803543  4.665996  11.683653 -1.941229 -2.860437   9.749073
# 996  0.854  0.977449  5.408350  11.690255  0.066929 -2.310025  11.288256
# 997  0.030  0.093712  3.678407  11.871393 -0.085895 -0.717800  13.515318
# 998  3.881  5.772867  0.973869  11.916999 -0.622275 -1.354238  10.650492
#
#             h         i          j
# 0   -0.082737 -0.316598   8.970595
# ...

# %%
df.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  999.000000  999.000000  999.000000  999.000000  999.000000  999.000000
# mean     2.000166    3.116052    2.923600    5.843904   -1.013893   -1.008192
# std      1.769124    2.087750    1.744819    2.605006    1.139024    1.364059
# min      0.000000    0.001504    0.002405    0.108732   -2.994304   -3.949744
# 25%      0.573000    1.349848    1.366898    3.893890   -1.968921   -2.060178
# 50%      1.479000    2.842602    2.887768    5.796502   -1.031533   -0.992511
# 75%      3.072000    4.715501    4.401428    7.776567   -0.034213    0.021726
# max      7.749000    7.905184    5.996989   11.916999    0.989519    1.916405
#
#                 g           h           i           j
# count  999.000000  999.000000  999.000000  999.000000
# mean    10.982195    0.257856   -0.377085    6.982758
# std      1.777580    0.444774    0.910509    7.451662
# ...

# %%
plt.plot(df[['a']],df[['b']],color='green')
plt.title('1 VS 2')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 2',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['c']],color='green')
plt.title('1 VS 3')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 3',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['d']],color='green')
plt.title('1 VS 4')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 4',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['e']],color='green')
plt.title('1 VS 5')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 5',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['f']],color='green')
plt.title('1 VS 6')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 6',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['g']],color='green')
plt.title('1 VS 7')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['h']],color='green')
plt.title('1 VS 8')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['i']],color='green')
plt.title('1 VS 9')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['a']],df[['j']],color='green')
plt.title('1 VS 10')
plt.ylabel('Feature 1',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['c']],color='green')
plt.title('2 VS 3')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 3',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['d']],color='green')
plt.title('2 VS 4')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 4',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['e']],color='green')
plt.title('2 VS 5')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 5',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['f']],color='green')
plt.title('2 VS 6')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 6',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['g']],color='green')
plt.title('2 VS 7')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['h']],color='green')
plt.title('2 VS 8')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['i']],color='green')
plt.title('2 VS 9')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['b']],df[['j']],color='green')
plt.title('2 VS 10')
plt.ylabel('Feature 2',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['d']],color='green')
plt.title('3 VS 4')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 4',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['e']],color='green')
plt.title('3 VS 5')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 5',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['f']],color='green')
plt.title('3 VS 6')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 6',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['g']],color='green')
plt.title('3 VS 7')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %% [markdown]
# # #This Plot classifies the Labels Perfectly#

# %%
plt.plot(df[['c']],df[['h']],color='orange')
plt.title('3 VS 8')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['i']],color='green')
plt.title('3 VS 9')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['c']],df[['j']],color='green')
plt.title('3 VS 10')
plt.ylabel('Feature 3',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['e']],color='green')
plt.title('4 VS 5')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 5',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['f']],color='green')
plt.title('4 VS 6')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 6',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['g']],color='green')
plt.title('4 VS 7')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['h']],color='green')
plt.title('4 VS 8')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['i']],color='green')
plt.title('4 VS 9')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['d']],df[['j']],color='green')
plt.title('4 VS 10')
plt.ylabel('Feature 4',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['e']],df[['f']],color='green')
plt.title('5 VS 6')
plt.ylabel('Feature 5',color='red')
plt.xlabel('Feature 6',color='blue')
plt.show()

# %%
plt.plot(df[['e']],df[['g']],color='green')
plt.title('5 VS 7')
plt.ylabel('Feature 5',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %%
plt.plot(df[['e']],df[['h']],color='green')
plt.title('5 VS 8')
plt.ylabel('Feature 5',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['e']],df[['i']],color='green')
plt.title('5 VS 9')
plt.ylabel('Feature 5',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['e']],df[['j']],color='green')
plt.title('5 VS 10')
plt.ylabel('Feature 5',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['f']],df[['g']],color='green')
plt.title('6 VS 7')
plt.ylabel('Feature 6',color='red')
plt.xlabel('Feature 7',color='blue')
plt.show()

# %%
plt.plot(df[['f']],df[['h']],color='green')
plt.title('6 VS 8')
plt.ylabel('Feature 6',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['f']],df[['i']],color='green')
plt.title('6 VS 9')
plt.ylabel('Feature 6',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['f']],df[['j']],color='green')
plt.title('6 VS 10')
plt.ylabel('Feature 6',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['g']],df[['h']],color='green')
plt.title('7 VS 8')
plt.ylabel('Feature 7',color='red')
plt.xlabel('Feature 8',color='blue')
plt.show()

# %%
plt.plot(df[['g']],df[['i']],color='green')
plt.title('7 VS 9')
plt.ylabel('Feature 7',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['g']],df[['j']],color='green')
plt.title('7 VS 10')
plt.ylabel('Feature 7',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['h']],df[['i']],color='green')
plt.title('8 VS 9')
plt.ylabel('Feature 8',color='red')
plt.xlabel('Feature 9',color='blue')
plt.show()

# %%
plt.plot(df[['h']],df[['j']],color='green')
plt.title('8 VS 10')
plt.ylabel('Feature 8',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
plt.plot(df[['j']],df[['i']],color='green')
plt.title('9 VS 10')
plt.ylabel('Feature 9',color='red')
plt.xlabel('Feature 10',color='blue')
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
x=df.loc[:,:].values

# %%
x=StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data=x).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.679113  1.274089  0.289958 -2.202699  0.761822 -0.830161 -1.664245
# 1 -0.528303 -1.244238  1.727531 -2.169671 -0.015494  1.236864  0.802998
# 2 -0.342242  1.470525  0.843103 -2.153771  0.621249 -0.105908  0.725502
# 3 -1.096100 -1.442120 -1.545761 -2.151698 -0.633306 -0.809235  0.872260
# 4 -0.330366  2.190881  0.443219 -2.084377  0.743631 -0.711274  1.087954
#
#           7         8         9
# 0 -0.766151  0.066466  0.266898
# 1 -0.708856  0.556694 -0.077329
# 2 -1.066243  1.133985  1.402117
# 3  1.650004  0.428463 -0.469310
# 4 -0.900677  1.264048  1.779273

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['PC1', 'PC2'])

# %%
principalDf.head(5)
# Out:
#         PC1       PC2
# 0 -0.179395  1.385414
# 1 -1.996569 -0.996592
# 2 -1.299359  0.453781
# 3  1.718595 -2.613735
# 4 -0.894040  0.591107

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['a'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['b'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['c'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['d'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['e'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['f'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['g'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['h'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['i'])
ax.grid()

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],principalDf['PC2'],c=df['j'])
ax.grid()

# %% [markdown]
# # # From this plot we get that 3rd and 8th feature seperates the best
# Therefore, taking them two at a time and obtaining the final plot

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 Component PCA', fontsize = 15)

ax.scatter(principalDf['PC1'],df['c'],principalDf['PC2'],df['h'])
ax.grid()

# %% [markdown]
# # From PCA and plot we conclude that lables 3 and 8 classify them perfectly
